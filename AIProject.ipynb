# %% [markdown]
# <a href="https://colab.research.google.com/github/raviteja1432/AI/blob/main/AIProject.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
from google.colab import drive 
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df = pd.read_csv("/content/drive/MyDrive/data.csv")
df.head()
# Out:
#    Unnamed: 0                         Brand me  ...  Battery_Power  Price
# 0           0            LG V30+ (Black, 128 )  ...           4000  24999
# 1           1                       I Kall K11  ...           4000  15999
# 2           2                     Nokia 105 ss  ...           4000  15000
# 3           3  Samsung Galaxy A50 (White, 64 )  ...           3800  18999
# 4           4       POCO F1 (Steel Blue, 128 )  ...           3800  18999
#
# [5 rows x 10 columns]

# %%
df.shape
# Out:
# (836, 10)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 836 entries, 0 to 835
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Unnamed: 0     836 non-null    int64
#  1   Brand me       836 non-null    object
#  2   Ratings        805 non-null    float64
#  3   RAM            829 non-null    float64
#  4   ROM            832 non-null    float64
#  5   Mobile_Size    834 non-null    float64
#  6   Primary_Cam    836 non-null    int64
#  7   Selfi_Cam      567 non-null    float64
#  8   Battery_Power  836 non-null    int64
#  9   Price          836 non-null    int64
# dtypes: float64(5), int64(4), object(1)
# memory usage: 65.4+ KB

# %%
df.isnull().sum()
# Out:
# Unnamed: 0         0
# Brand me           0
# Ratings           31
# RAM                7
# ROM                4
# Mobile_Size        2
# Primary_Cam        0
# Selfi_Cam        269
# Battery_Power      0
# Price              0
# dtype: int64

# %%
df = df[['Ratings', 'RAM', 'ROM', 'Mobile_Size',
       'Primary_Cam', 'Selfi_Cam', 'Battery_Power', 'Price']]

# %%
df
# Out:
#      Ratings   RAM    ROM  ...  Selfi_Cam  Battery_Power  Price
# 0        4.3   4.0  128.0  ...       13.0           4000  24999
# 1        3.4   6.0   64.0  ...       12.0           4000  15999
# 2        4.3   4.0    4.0  ...       16.0           4000  15000
# 3        4.4   6.0   64.0  ...       15.0           3800  18999
# 4        4.5   6.0  128.0  ...       15.0           3800  18999
# ..       ...   ...    ...  ...        ...            ...    ...
# 831      3.8   6.0   32.0  ...       12.0           2800   1299
# 832      4.1   8.0   64.0  ...        NaN           2500   1390
# 833      4.4   3.0   32.0  ...        1.0           3800   9790
# 834      3.7  10.0   32.0  ...        NaN           3500    799
# 835      3.5   6.0   32.0  ...       15.0           1050    799
#
# [836 rows x 8 columns]

# %%
df.isnull().sum()
# Out:
# Ratings           31
# RAM                7
# ROM                4
# Mobile_Size        2
# Primary_Cam        0
# Selfi_Cam        269
# Battery_Power      0
# Price              0
# dtype: int64

# %%
df['Ratings'] = df['Ratings'].fillna(df['Ratings'].mean())
df['RAM'] = df['RAM'].fillna(df['RAM'].mean())
df['ROM'] = df['ROM'].fillna(df['ROM'].mean())
df['Mobile_Size'] = df['Mobile_Size'].fillna(df['Mobile_Size'].mean())
df['Selfi_Cam'] = df['Selfi_Cam'].fillna(df['Selfi_Cam'].mean())

# %%
df['RAM'] = df['RAM'].astype('int64')
df['ROM'] = df['ROM'].astype('int64')
df['Selfi_Cam'] = df['Selfi_Cam'].astype('int64')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 836 entries, 0 to 835
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Ratings        836 non-null    float64
#  1   RAM            836 non-null    int64
#  2   ROM            836 non-null    int64
#  3   Mobile_Size    836 non-null    float64
#  4   Primary_Cam    836 non-null    int64
#  5   Selfi_Cam      836 non-null    int64
#  6   Battery_Power  836 non-null    int64
#  7   Price          836 non-null    int64
# dtypes: float64(2), int64(6)
# memory usage: 52.4 KB

# %%
df.describe()
# Out:
#           Ratings         RAM  ...  Battery_Power         Price
# count  836.000000  836.000000  ...     836.000000     836.00000
# mean     4.103106    6.065789  ...    3274.688995   18220.34689
# std      0.358510    2.519714  ...     927.518852   52805.55022
# min      2.800000    0.000000  ...    1020.000000     479.00000
# 25%      3.900000    6.000000  ...    3000.000000     984.75000
# 50%      4.101553    6.000000  ...    3000.000000    1697.00000
# 75%      4.400000    6.000000  ...    3800.000000   18999.00000
# max      4.800000   34.000000  ...    6000.000000  573000.00000
#
# [8 rows x 8 columns]

# %%
corr = df.corr()
corr.shape
# Out:
# (8, 8)

# %%
plt.figure(figsize=(14,14))
sns.heatmap(corr, cbar=False, square= True, fmt='.2%', annot=True, cmap='Blues')

# %%
sns.heatmap(df.isnull(),yticklabels=False,cbar=False,cmap='viridis')

# %%
plt.figure(figsize=(15,10))
sns.set_style('whitegrid')
sns.countplot(x='Ratings',data=df)

# %%
plt.figure(figsize=(15,10))
sns.set_style('whitegrid')
sns.countplot(x='RAM',data=df)

# %%
plt.figure(figsize=(15,10))
sns.set_style('whitegrid')
sns.countplot(x='ROM',data=df)

# %%
plt.figure(figsize=(15,10))
sns.set_style('whitegrid')
sns.countplot(x='Primary_Cam',data=df)

# %%
plt.figure(figsize=(15,10))
sns.set_style('whitegrid')
sns.countplot(x='Selfi_Cam',data=df)

# %%
sns.displot(df['RAM'].dropna(),kde=False,color='darkred',bins=10)

# %%
sns.displot(df['Battery_Power'].dropna(),kde=False,color='blue',bins=10)

# %%
sns.displot(df['Price'].dropna(),kde=False,color='purple',bins=15)

# %%
sns.displot(df['Battery_Power'].dropna(),kde=False,color='green',bins=15)

# %%
plt.figure(figsize=(10,10))
sns.pairplot(data=df)

# %%
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2

# %%
X = df.iloc[:,1:7] # Independent columns
y = df.iloc[:,[-1]] # Y target column i.e price range

# %%
bestfeatures = SelectKBest(score_func=chi2, k=4)
fit = bestfeatures.fit(X,y)

# %%
dfscores = pd.DataFrame(fit.scores_)
dfcolumns = pd.DataFrame(X.columns)
# Concat two dataframes for better visualization
featureScores = pd.concat([dfcolumns,dfscores],axis=1)
featureScores.columns = ['Specs','Score'] #naming the dataframe columns
featureScores
# Out:
#            Specs          Score
# 0            RAM     605.009453
# 1            ROM   31222.209834
# 2    Mobile_Size     874.471349
# 3    Primary_Cam    1465.379223
# 4      Selfi_Cam    1358.898574
# 5  Battery_Power  156629.116310

# %%
print(featureScores.nlargest(4,'Score')) #print 4 best features
# Out:
#            Specs          Score
# 5  Battery_Power  156629.116310
# 1            ROM   31222.209834
# 3    Primary_Cam    1465.379223
# 4      Selfi_Cam    1358.898574

# %%
from sklearn.ensemble import ExtraTreesClassifier
import matplotlib.pyplot as plt
model = ExtraTreesClassifier()
model.fit(X,y)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   after removing the cwd from sys.path.
# ExtraTreesClassifier()

# %%
print(model.feature_importances_) 
feat_importances = pd.Series(model.feature_importances_, index=X.columns)
feat_importances.nlargest(10).plot(kind='barh')
plt.show()
# Out:
# [0.11624896 0.10485147 0.25805852 0.09257567 0.22416845 0.20409692]

# %%
x = df.iloc[:,[6,2,4,5,1,3]]
y = df.iloc[:,[-1]]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X, y, test_size=0.25, random_state=15)

# %%
from sklearn.ensemble import RandomForestRegressor
reg = RandomForestRegressor(max_depth=8)
reg.fit(X_train,y_train)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   This is separate from the ipykernel package so we can avoid doing imports until
# RandomForestRegressor(max_depth=8)

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X, y, test_size=0.25, random_state=15)

# %%
regressor = SVR(kernel = 'rbf')
regressor.fit(X, y)
# Out:
# /usr/local/lib/python3.7/dist-packages/sklearn/utils/validation.py:985: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# SVR()

# %% [markdown]
# Random Forest Regressor

# %%
y_pred = reg.predict(X_train)
print("Training Accuracy:",reg.score(X_train,y_train)*100)
# Out:
# Training Accuracy: 95.31219215827403

# %%
print("Testing Accuracy:",reg.score(X_test,y_test)*100)
# Out:
# Testing Accuracy: 93.79666899285098

# %%
plt.scatter(y_train, y_pred)
plt.xlabel("Price")
plt.ylabel("Predicted Price")
plt.title("Price vs Predicted Price")
plt.show()

# %%
y_pred = regressor.predict(X_train)
print("Training Accuracy:",reg.score(X_train,y_train)*100)
# Out:
# Training Accuracy: 95.31219215827403

# %%
print("Testing Accuracy:",reg.score(X_test,y_test)*100)
# Out:
# Testing Accuracy: 93.79666899285098

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
dt=DecisionTreeRegressor(max_depth=8)
dt.fit(X_train,y_train)
# Out:
# DecisionTreeRegressor(max_depth=8)

# %%
dt.score(X_train,y_train)*100
# Out:
# 97.22605926858266

# %%
dt.score(X_test,y_test)*100
# Out:
# 95.88138856452404

# %%
from sklearn.linear_model import LinearRegression

# %%
model=LinearRegression()
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
model.score(X_train,y_train)*100
# Out:
# 13.447453391804565

# %%
model.score(X_test,y_test)*100
# Out:
# 11.582895173205177

# %%
from sklearn.tree import DecisionTreeRegressor
dt=DecisionTreeRegressor()
dt.fit(X_train,y_train)
print(dt.score(X_test,y_test)*100)
print(dt.score(X_train,y_train)*100)
# Out:
# 94.73262380454705
# 97.96913411674413

# %%
import pickle
pickle.dump(model,open('model.pkl','wb'))
